# %%
from enum import Enum 

class Modification(Enum):
    ADDED = "Lines added"
    REMOVED = "Lines removed"
    TOTAL = "Lines added + lines removed"
    DIFF = "Lines added - lines removed"

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in ./.env/lib/python3.10/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydriller
from collections import defaultdict
import tqdm
from pathlib import Path
from git import Repo
from datetime import datetime

#Path to Repo
path_to_repo = "./mastodon"
repo_path = Path('./mastodon')

#From/To Tags
start_tag =  'v3.5.0'
current_tag = 'v3.5.3'

#Starting/End date YYYY,M,D
start_date = datetime(2019,1,1)
end_date = datetime(2019,12,31)

#File type --> if all files need to be considered ""
file_type = '.rb'

#if we need to consider only one path 
#--> SE1="app\\""  --> SE2=whole
path_spec = ''

# Clone the repository
if repo_path.exists():
    print('Repository exists!')
else:
    #  clone using the python git library
    Repo.clone_from('https://github.com/mastodon/mastodon', path_to_repo)

#Repo from to start tag
repo = pydriller.Repository(path_to_repo, from_tag=start_tag, to_tag=current_tag)

#Repo from since start to --> time
#repo = pydriller.Repository(path_to_repo, since=start_date, to=end_date)

#List with all commits
commits = list(repo.traverse_commits())
progress = tqdm.tqdm(unit="commit", total=len(commits))

#unique files / authors (set)
files_by_author = defaultdict(set)
authors_per_file = defaultdict(set)
commit_hashes = []
files_2 = []


#detect only modified files --> created/deleted files are not intresting
for commit in commits:
    commit_hashes.append(commit.hash)
    for modified_file in commit.modified_files:
        author = commit.author.name.strip()
        file = str(modified_file.new_path)
        
        if not file:
            continue
            
        if not file.endswith(file_type):
            continue
        
        if not file.startswith(path_spec):
            continue

        files_2.append(modified_file)
        files_by_author[author].add(file)        
        authors_per_file[file].add(author)
    
    progress.update(1)
# Out:
# Repository exists!
#  93%|█████████▎| 199/214 [00:02<00:00, 73.35commit/s]

# %%
#Accessing single commit
c = commits[0]

#Acessing path of modified file
print(c.modified_files[0].new_path)
print(c.author.name)
print(c.author.email)
# Out:
# CHANGELOG.md
# Eugen Rochko
# eugen@zeonfederated.com

# %% [markdown]
# # **Hash**

# %%
# CALL ANYTHING ON A SPECIFIC COMMIT by HASH

# ----------------------------------
#INDEX = commit_hashes.index('a01580f09f33c275fcc0ffe616b5b5b403f46cae')
#commits[INDEX].insertions

# %%
def get_commit_info_from_hash(c_hash):
    git = pydriller.Git(path_to_repo)
    commit = git.get_commit(c_hash)
    print("Name: ", commit.author.name)
    print("Date: ", commit.author_date)
    print("Commit message: ", commit.msg)
    print("Hash: ", commit.hash)
    print("Number of files: ", commit.files)
    print("Insertions: ", commit.insertions)
    print("Deletions: ", commit.deletions)
    print("Modified files: ")
    for f in commit.modified_files: print("* ", f.new_path, "   +",  f.added_lines, "   -", f.deleted_lines)

#get_commit_info_from_hash('a01580f09f33c275fcc0ffe616b5b5b403f46cae')

# %%
# EXAMPLE: INSERTIONS
# commit_xy = [(commit.hash, commit.insertions) for commit in commits]
# commit_xy

# EXAMPLE: MODIFIED_FILES
#commit_xx = [(commit.hash, commit.modified_files) for commit in commits]
#commit_xx

# %% [markdown]
# # **Unique Author**

# %%
#find unique authors in commits
authors = []
authors_total = []
modified_files = 0

for commit in commits:
    authors_total.append(commit.author.name)
    name = commit.author.name
    modified_files += len(commit.modified_files)

    if name not in authors:
        authors.append(name)

#print("Authors Total: ", authors_total)    
print("Number of unique authors: ", len(set(authors)))
print("Number of total authors: ", len(authors_total))
print('Total Number of modified files: ', modified_files)
print("Unique Authors: \n", authors)
# Out:
# Number of unique authors:  19
# Number of total authors:  214
# Total Number of modified files:  1524
# Unique Authors:
#  ['Eugen Rochko', 'Claire', 'Holger', 'dependabot[bot]', 'Ondřej Pokorný', 'CommanderRoot', 'rinsuki', 'Yamagishi Kazutoshi', '0x2019', 'dogelover911', 'Alexandra Catalina', 'Jeong Arm', 'Chris Dzombak', 'Gaelan Steele', 'mayaeh', 'Sara Golemon', 'Stefano Pigozzi', 'luzpaz', 'James Smith']

# %% [markdown]
# # **Number of Commits per Author**

# %%
# find number of commits
print("Total commits: ",len(commits))

# find number of commits per author
commits_per_author = {}
for author in authors_total:
    if author not in commits_per_author:
        commits_per_author[author] = 1
    else:
        commits_per_author[author] += 1

commits_per_author_sorted = sorted(commits_per_author.items(), key=lambda x:x[1], reverse=True)
print(commits_per_author_sorted)

Total_commits = list(commits_per_author.values())
print("Total commits: ",sum(Total_commits))
# Out:
# Total commits:  214
# [('dependabot[bot]', 85), ('Eugen Rochko', 56), ('Claire', 45), ('Yamagishi Kazutoshi', 9), ('Jeong Arm', 3), ('Holger', 2), ('rinsuki', 2), ('Ondřej Pokorný', 1), ('CommanderRoot', 1), ('0x2019', 1), ('dogelover911', 1), ('Alexandra Catalina', 1), ('Chris Dzombak', 1), ('Gaelan Steele', 1), ('mayaeh', 1), ('Sara Golemon', 1), ('Stefano Pigozzi', 1), ('luzpaz', 1), ('James Smith', 1)]
# Total commits:  214

# %% [markdown]
# # **Number of Files per Author**

# %%
files_by_author_count = { author : len(files_by_author[author]) for author in files_by_author}
files_by_author_count = {k: v for k, v in sorted(files_by_author_count.items(), key=lambda item: item[1], reverse=True)}
files_by_author_count
# Out:
# {'Eugen Rochko': 127,
#  'Claire': 51,
#  'Holger': 3,
#  '0x2019': 3,
#  'Jeong Arm': 3,
#  'Yamagishi Kazutoshi': 2,
#  'Stefano Pigozzi': 2,
#  'rinsuki': 1,
#  'dogelover911': 1,
#  'Sara Golemon': 1,
#  'luzpaz': 1}

# %% [markdown]
# # **Number of Authors working per File**

# %%
authors_per_file_count = { file : len(authors_per_file[file]) for file in authors_per_file}
sorted(authors_per_file_count.items(), key=lambda x:x[1], reverse=True)
# Out:
# [('app/chewy/statuses_index.rb', 3),
#  ('app/lib/feed_manager.rb', 3),
#  ('app/helpers/application_helper.rb', 3),
#  ('lib/mastodon/version.rb', 2),
#  ('app/helpers/formatting_helper.rb', 2),
#  ('app/models/status.rb', 2),
#  ('config/application.rb', 2),
#  ('app/services/remove_status_service.rb', 2),
#  ('app/mailers/user_mailer.rb', 2),
#  ('app/services/activitypub/fetch_featured_collection_service.rb', 2),
#  ('app/services/activitypub/process_status_update_service.rb', 2),
#  ('config/environments/production.rb', 2),
#  ('app/lib/activitypub/activity/create.rb', 2),
#  ('db/schema.rb', 2),
#  ('app/services/resolve_account_service.rb', 2),
#  ('config/initializers/stoplight.rb', 2),
#  ('app/lib/activitypub/activity/announce.rb', 2),
#  ('app/serializers/manifest_serializer.rb', 1),
#  ('config/initializers/paperclip.rb', 1),
#  ('app/serializers/rest/status_serializer.rb', 1),
#  ('app/controllers/api/v1/trends/tags_controller.rb', 1),
#  ('app/controllers/api/v1/admin/account_actions_controller.rb', 1),
#  ('app/controllers/api/v1/admin/accounts_controller.rb', 1),
#  ('app/controllers/api/v1/admin/dimensions_controller.rb', 1),
#  ('app/controllers/api/v1/admin/measures_controller.rb', 1),
#  ('app/controllers/api/v1/admin/reports_controller.rb', 1),
#  ('app/controllers/api/v1/admin/retention_controller.rb', 1),
#  ('app/controllers/api/v1/admin/trends/links_controller.rb', 1),
#  ('app/controllers/api/v1/admin/trends/statuses_controller.rb', 1),
#  ('app/controllers/api/v1/admin/trends/tags_controller.rb', 1),
#  ('app/controllers/auth/sessions_controller.rb', 1),
#  ('app/lib/suspicious_sign_in_detector.rb', 1),
#  ('app/models/user.rb', 1),
#  ('app/policies/user_policy.rb', 1),
#  ('config/routes.rb', 1),
#  ('lib/mastodon/accounts_cli.rb', 1),
#  ('spec/controllers/auth/sessions_controller_spec.rb', 1),
#  ('spec/lib/suspicious_sign_in_detector_spec.rb', 1),
#  ('spec/mailers/previews/user_mailer_preview.rb', 1),
#  ('spec/services/activitypub/fetch_remote_status_service_spec.rb', 1),
#  ('spec/services/activitypub/process_status_update_service_spec.rb', 1),
#  ('spec/mailers/user_mailer_spec.rb', 1),
#  ('app/controllers/api/v1/trends/links_controller.rb', 1),
#  ('app/controllers/api/v1/trends/statuses_controller.rb', 1),
#  ('app/models/trends/query.rb', 1),
#  ('lib/mastodon/migration_helpers.rb', 1),
#  ('config/initializers/devise.rb', 1),
#  ('config/initializers/session_store.rb', 1),
#  ('app/models/trends/base.rb', 1),
#  ('app/models/trends/statuses.rb', 1),
#  ('app/controllers/settings/preferences_controller.rb', 1),
#  ('app/lib/user_settings_decorator.rb', 1),
#  ('app/services/notify_service.rb', 1),
#  ('app/controllers/api/v1/statuses_controller.rb', 1),
#  ('app/models/trends/links.rb', 1),
#  ('app/controllers/api/v2/search_controller.rb', 1),
#  ('app/lib/search_query_transformer.rb', 1),
#  ('lib/exceptions.rb', 1),
#  ('app/models/account_alias.rb', 1),
#  ('app/serializers/web/notification_serializer.rb', 1),
#  ('app/models/account.rb', 1),
#  ('app/models/concerns/account_finder_concern.rb', 1),
#  ('db/migrate/20190715164535_add_instance_actor.rb', 1),
#  ('spec/lib/activitypub/activity/create_spec.rb', 1),
#  ('db/migrate/20220428112511_add_index_statuses_on_account_id.rb', 1),
#  ('db/migrate/20220428112727_add_index_statuses_pins_on_status_id.rb', 1),
#  ('db/migrate/20220428114454_add_index_reports_on_assigned_account_id.rb', 1),
#  ('db/migrate/20220428114902_add_index_reports_on_action_taken_by_account_id.rb',
#   1),
#  ('app/controllers/admin/dashboard_controller.rb', 1),
#  ('app/controllers/media_proxy_controller.rb', 1),
#  ('app/controllers/settings/exports_controller.rb', 1),
#  ('app/lib/access_token_extension.rb', 1),
#  ('app/lib/activitypub/activity.rb', 1),
#  ('app/lib/delivery_failure_tracker.rb', 1),
#  ('app/lib/redis_configuration.rb', 1),
#  ('app/models/account_conversation.rb', 1),
#  ('app/models/account_suggestions/global_source.rb', 1),
#  ('app/models/concerns/redisable.rb', 1),
#  ('app/models/custom_filter.rb', 1),
#  ('app/models/encrypted_message.rb', 1),
#  ('app/models/follow_recommendation_filter.rb', 1),
#  ('app/services/activitypub/process_account_service.rb', 1),
#  ('app/services/fan_out_on_write_service.rb', 1),
#  ('app/services/fetch_link_card_service.rb', 1),
#  ('app/services/precompute_feed_service.rb', 1),
#  ('app/services/vote_service.rb', 1),
#  ('app/workers/distribution_worker.rb', 1),
#  ('app/workers/merge_worker.rb', 1),
#  ('app/workers/scheduler/accounts_statuses_cleanup_scheduler.rb', 1),
#  ('config/initializers/sidekiq.rb', 1),
#  ('lib/mastodon/feeds_cli.rb', 1),
#  ('lib/mastodon/rack_middleware.rb', 1),
#  ('lib/mastodon/redis_config.rb', 1),
#  ('lib/mastodon/sidekiq_middleware.rb', 1),
#  ('spec/controllers/concerns/user_tracking_concern_spec.rb', 1),
#  ('spec/lib/activitypub/activity/move_spec.rb', 1),
#  ('spec/lib/delivery_failure_tracker_spec.rb', 1),
#  ('spec/lib/feed_manager_spec.rb', 1),
#  ('spec/models/home_feed_spec.rb', 1),
#  ('spec/rails_helper.rb', 1),
#  ('spec/services/after_block_service_spec.rb', 1),
#  ('spec/services/batched_remove_status_service_spec.rb', 1),
#  ('spec/services/fan_out_on_write_service_spec.rb', 1),
#  ('spec/services/mute_service_spec.rb', 1),
#  ('spec/services/precompute_feed_service_spec.rb', 1),
#  ('spec/workers/scheduler/feed_cleanup_scheduler_spec.rb', 1),
#  ('app/services/resolve_url_service.rb', 1),
#  ('spec/services/resolve_url_service_spec.rb', 1),
#  ('app/controllers/api/v1/bookmarks_controller.rb', 1),
#  ('app/controllers/api/v1/favourites_controller.rb', 1),
#  ('app/models/trends/tags.rb', 1),
#  ('lib/mastodon/cli_helper.rb', 1),
#  ('lib/mastodon/search_cli.rb', 1),
#  ('spec/services/resolve_account_service_spec.rb', 1),
#  ('app/models/email_domain_block.rb', 1),
#  ('app/validators/email_mx_validator.rb', 1),
#  ('db/migrate/20180615122121_add_autofollow_to_invites.rb', 1),
#  ('db/post_migrate/20220429101025_remove_ips_from_email_domain_blocks.rb', 1),
#  ('db/post_migrate/20220429101850_clear_email_domain_blocks.rb', 1),
#  ('spec/validators/email_mx_validator_spec.rb', 1),
#  ('app/lib/webfinger.rb', 1),
#  ('app/controllers/oauth/tokens_controller.rb', 1),
#  ('app/controllers/authorize_interactions_controller.rb', 1),
#  ('app/controllers/following_accounts_controller.rb', 1),
#  ('app/controllers/api/v1/accounts/lookup_controller.rb', 1),
#  ('spec/services/activitypub/fetch_featured_collection_service_spec.rb', 1),
#  ('lib/mastodon/settings_cli.rb', 1),
#  ('app/services/verify_link_service.rb', 1),
#  ('app/helpers/statuses_helper.rb', 1),
#  ('app/models/admin/account_action.rb', 1),
#  ('app/controllers/accounts_controller.rb', 1),
#  ('app/controllers/tags_controller.rb', 1),
#  ('app/lib/emoji_formatter.rb', 1),
#  ('app/lib/rss/builder.rb', 1),
#  ('app/lib/rss/channel.rb', 1),
#  ('app/lib/rss/element.rb', 1),
#  ('app/lib/rss/item.rb', 1),
#  ('app/lib/rss/media_content.rb', 1),
#  ('spec/lib/emoji_formatter_spec.rb', 1),
#  ('spec/controllers/settings/two_factor_authentication/confirmations_controller_spec.rb',
#   1),
#  ('app/serializers/rest/account_serializer.rb', 1),
#  ('app/lib/activitypub/activity/delete.rb', 1),
#  ('app/models/account_migration.rb', 1),
#  ('app/models/concerns/lockable.rb', 1),
#  ('app/serializers/initial_state_serializer.rb', 1),
#  ('app/serializers/rest/preferences_serializer.rb', 1),
#  ('app/services/activitypub/fetch_remote_status_service.rb', 1),
#  ('spec/services/fetch_remote_status_service_spec.rb', 1),
#  ('app/chewy/accounts_index.rb', 1),
#  ('app/chewy/tags_index.rb', 1),
#  ('app/workers/scheduler/indexing_scheduler.rb', 1),
#  ('config/initializers/chewy.rb', 1),
#  ('lib/chewy/strategy/mastodon.rb', 1),
#  ('app/lib/importer/accounts_index_importer.rb', 1),
#  ('app/lib/importer/base_importer.rb', 1),
#  ('app/lib/importer/statuses_index_importer.rb', 1),
#  ('app/lib/importer/tags_index_importer.rb', 1),
#  ('app/models/trends/history.rb', 1),
#  ('app/controllers/api/v1/accounts_controller.rb', 1),
#  ('app/services/process_mentions_service.rb', 1),
#  ('spec/models/account_spec.rb', 1),
#  ('app/models/poll.rb', 1),
#  ('app/models/account_stat.rb', 1),
#  ('app/models/status_stat.rb', 1),
#  ('app/controllers/auth/confirmations_controller.rb', 1),
#  ('app/lib/application_extension.rb', 1),
#  ('config/initializers/doorkeeper.rb', 1),
#  ('app/controllers/activitypub/base_controller.rb', 1),
#  ('app/controllers/api/base_controller.rb', 1),
#  ('app/services/approve_appeal_service.rb', 1),
#  ('app/models/admin/status_batch_action.rb', 1),
#  ('app/services/report_service.rb', 1),
#  ('app/services/appeal_service.rb', 1),
#  ('app/services/unfollow_service.rb', 1),
#  ('app/helpers/languages_helper.rb', 1)]

# %% [markdown]
# # **Lines added per Commit**

# %%
#Number added lines within a commit
commit_lines = dict()
for commit in commits:
    commit_lines[commit.hash] = 0
    for file in commit.modified_files:
        if file.filename.endswith(file_type):
            commit_lines[commit.hash] += file.added_lines

print("Number of commits:", len(commit_lines))
print(sorted(commit_lines.items(), key=lambda x:x[1], reverse=True))
# Out:
# Number of commits: 214
# [('a9b64b24d6c076cb96a66307c07d4f0158dc07da', 294), ('3917353645b91dae04f7d9b81162fead6f73072a', 243), ('2b8dc58b7ff7fb708687c08a75c99b3fb30efc49', 233), ('8f91e304a5adb98b657a5c096359d0423a5d7e84', 220), ('440eb71310e41d668f00980b73358edd5f8df043', 194), ('71d02ffcf3a79dfc1c413dcc7ff45c77ce9cb94c', 146), ('6221b36b278c02cdbf5b6d1c0753654b506b44fd', 115), ('6cf57c676550068a59149ca82d63fcb5b5431158', 115), ('6476f7e4da4da7c353d497aae5a86fc3909ce532', 81), ('679b7158e3cd3881e8cbaf2d2c0c97725b3b5fd9', 59), ('0360135d4d39d838fa9b090abc1e76284eb8ff64', 53), ('8e20e16cf030fef48850df4764bbf13a317f6b0c', 50), ('f6d35ed57d156f4225338a89372c8e83721e46c9', 43), ('e0bdaeab657d9a320aaf506d98ca82d41e7bfdd5', 42), ('9b4024a3892c48aaf2f6e86fc014360f2dd098f4', 34), ('7b0fe4aef97c6a5f73a03146b669a415f396799c', 28), ('3e0e7a1cfb617837ccada330afc13ed804c3c47b', 24), ('39b489ba4c362997b41dd039971b8b510f6fe10d', 20), ('84d991988eb076a7d83c771b3266f66f1c8a9754', 20), ('465ee7792ff48905088efdf3df6f718081b5e244', 16), ('fd9a9b07c2cd19ef08d15e138fd3fc59fc5318b6', 16), ('33cd80d69c1491ff70ce9191113763c76cb7e6b7', 15), ('bc19c083cef6f66d28528d79548cf692fa8a2ca6', 14), ('454ef42aab48e73613c4588faaacfb5941bd3e6a', 13), ('ef196c913c77338be5ebb1e02af2f6225f857080', 12), ('ce9dcbea32e7212dc19d83bbb7a21afe8756ced0', 12), ('96129c2f10a82520648f6ae04e585cf797403617', 12), ('6da648227ef59e5c77dc9d2c89a39eb5496a153e', 11), ('0a1992430db7a859b3b7faa3d9ce4f07734b5fd8', 11), ('68273a7c6d6c630b6c88764579580682e12eebce', 9), ('012537452a1b9087ea085253e8d42fe4129cea42', 9), ('33f3818d660c67194f94c7ff2bb180f4865e6748', 9), ('ea383278160bcee81477e86a95107d4a2dc315ef', 7), ('0cdb07757050825725cac76f1c9cf11cf64acc0a', 7), ('3906dd67ed84f963238f9bdccef63fe3fd3a05aa', 6), ('b9197486e5bb0710526d6155347cc2c6f8b5948a', 6), ('b4d373a3df2752d9f8bdc0d7f02350528f3789b2', 6), ('9f81b9f29a14093cefcdbf09058ace089cd8e06b', 6), ('c4d2c39a75eccdbc60c3540c259e1e7ea5881ac6', 6), ('0a8a0fb5990eb6d3842948654d0b6140e776d8a9', 5), ('dc503472477000597f2ff1b6a5c37e8ac4dd2d8c', 5), ('52f4e834f293c9fdbf5805639d022ac4e3856b75', 5), ('275dad97024d010853d995350b5224c0a3edc400', 4), ('a53003c6f18cd5b4177810e118b158290131b6ec', 4), ('ea0cfd8e7ed41b32aaa47eabb1c73845ae843fcb', 3), ('8c03b45fffc54a66d1c9c3eec75a7c6f741d0947', 3), ('5f0fc639dada7a58d2bb5524b4ec081ee6cc143f', 3), ('b93e2ae0a4b6e9ea7e3d3ea721ad46d43cb4eedb', 3), ('9a3be0ad688ea80fffee78635395141ad2419e8a', 3), ('6c699b17234355598d6d3237e8826adf6f0688f9', 3), ('abb11778d7d9ac04fe1feeccf5cefc6d2ed58780', 2), ('6e418bf3465d2df6b47e9b43d3b960504b81e8fb', 2), ('66a63d79ea11641c3e15cf65785be464cf3695bc', 2), ('5a48bf1085f9fd4f10ea3706bacfe3b18fcc725c', 2), ('99d7684dfdd362ded673e474403afb88a6cc0419', 2), ('898fe2fa8e886d62de2bd9b15eb758054216d33d', 2), ('e5997a195602624efdb366e9f09ffa377e859580', 2), ('088dc0ec5a383006952c0b15508af882a4c1109c', 2), ('976cd6413e9b2a1531a2ad17945342deaeec538c', 2), ('1ff4877945e18820f3e518a1cfbac243da65e1a5', 2), ('8a9acbe604667215c9589154d72b3f313755c210', 2), ('8c7223f4eac80b5725485be742d3fa2c984f4670', 1), ('d116cb7733bb535bb72207b20fba9a7d0da371ed', 1), ('cb45c04d2642291cedd85b2483f0d827d130d6e2', 1), ('ed5491e5de6ede501715c421ad5fa53493f61250', 1), ('4c9949560dacac8053cc44a5364534c215ac3a93', 1), ('1de748bf5e775b7b5f6b45b73d90772cba899a6d', 1), ('5781d1db841ff7f81301cd28acecc5331a68d97e', 1), ('8ffa96b0595958e35ed44308a6801d3ea3160968', 1), ('8284110c55679b7ce7b3922cb0559620b03ca88c', 1), ('6726d2933a25137f8dce639c53da8aa1752be47e', 1), ('6e4d932da53ba236699285ce2bdfcfa07b259fa2', 1), ('0597e5db68a4b43b69d3bfcb93d0b0042d91b17f', 1), ('014065913ca59ae58559239eabd49f5c06e62dbc', 1), ('336c23336addeaf5dba42007dd2a5b3c06795d71', 1), ('c3fac61f56b3ad63534961f3d3c426cdf8ac6213', 1), ('25dda3061e4308a5005d3a2fef373acffc510a66', 1), ('fbcbf7898f000d9d1a21d52e8a8d3ed4602aa7db', 1), ('24d446adf22644c61e4d61ef612458cf087326dd', 0), ('44b7be45f1161d6378dba13e083b3c05d90cf0fa', 0), ('80ded02a4bd2ea6d5b9b69198753063224773f66 ...

# %% [markdown]
# # **Entities**

# %%
# find number of changes per file
changes = {}
for commit in commits:
    for mod in commit.modified_files:
        if mod.filename not in changes:
            changes[mod.filename] = 1
        else:
            changes[mod.filename] += 1
print("Number of changes: ", len(changes))
#print(changes)
print("Number of entities",  sum(list(changes.values())))
# Out:
# Number of changes:  520
# Number of entities 1524

# %%
# find number of entities and number of unique entities
entities = []
entities_unique = set()
for commit in commits:
    for mod in commit.modified_files:
        entities.append(mod.filename)
        entities_unique.add(mod.filename)
        #print(mod.filename)
print("Number of Total entities: ", len(entities))
print("Number of different entities: ", len(entities_unique))
# Out:
# Number of Total entities:  1524
# Number of different entities:  520

# %% [markdown]
# # **Knowledge loss**

# %%
repo = pydriller.Repository(path_to_repo, from_tag=start_tag, to_tag=current_tag)

method = Modification.TOTAL

commits = list(repo.traverse_commits())
progress = tqdm.tqdm(unit="commit", total=len(commits))

#files per author
files_authors = defaultdict(dict)

#detect lines added per file and author
for commit in commits:
    for modified_file in commit.modified_files:
        author = commit.author.name.strip()
        file = str(modified_file.new_path)

        if not file:
            continue

        if not file.endswith(file_type):
            continue

        if author not in files_authors[file]:
            files_authors[file][author] = 0
            
        if method == Modification.ADDED:
            files_authors[file][author] += modified_file.added_lines
        elif method == Modification.REMOVED:
            files_authors[file][author] += modified_file.deleted_lines
        elif method == Modification.TOTAL:
            files_authors[file][author] += modified_file.added_lines + modified_file.deleted_lines
        elif method == Modification.DIFF:
            files_authors[file][author] += modified_file.added_lines - modified_file.deleted_lines
        
    progress.update(1)

files_authors
# Out:
# 100%|██████████| 214/214 [00:03<00:00, 66.08commit/s]
# defaultdict(dict,
#             {'lib/mastodon/version.rb': {'Eugen Rochko': 6, 'Claire': 2},
#              'app/chewy/statuses_index.rb': {'Claire': 2,
#               'Jeong Arm': 5,
#               'Eugen Rochko': 4},
#              'app/helpers/formatting_helper.rb': {'Claire': 1,
#               'Eugen Rochko': 28},
#              'app/lib/feed_manager.rb': {'Claire': 23,
#               'dogelover911': 2,
#               'Eugen Rochko': 6},
#              'app/models/status.rb': {'Claire': 13, 'Jeong Arm': 2},
#              'app/serializers/manifest_serializer.rb': {'Holger': 6},
#              'config/application.rb': {'Holger': 1, 'Eugen Rochko': 5},
#              'config/initializers/paperclip.rb': {'Holger': 20},
#              'app/helpers/application_helper.rb': {'Claire': 7,
#               'Stefano Pigozzi': 2,
#               'Eugen Rochko': 4},
#              'app/serializers/rest/status_serializer.rb': {'rinsuki': 4},
#              'app/controllers/api/v1/trends/tags_controller.rb': {'Eugen Rochko': 8},
#              'app/controllers/api/v1/admin/account_actions_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/accounts_controller.rb': {'Claire': 5},
#              'app/controllers/api/v1/admin/dimensions_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/measures_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/reports_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/retention_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/trends/links_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/trends/statuses_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/admin/trends/tags_controller.rb': {'Claire': 2},
#              'app/services/remove_status_service.rb': {'Claire': 4,
#               'Eugen Rochko': 63},
#              'app/controllers/auth/sessions_controller.rb': {'Eugen Rochko': 9},
#              'app/lib/suspicious_sign_in_detector.rb': {'Eugen Rochko': 42},
#              'app/mailers/user_mailer.rb': {'Eugen Rochko': 12, 'Claire': 1},
#              'app/models/user.rb': {'Eugen Rochko': 24},
#              'app/policies/user_policy.rb': {'Eugen Rochko': 8},
#              'config/routes.rb': {'Eugen Rochko': 1},
#              'lib/mastodon/accounts_cli.rb': {'Eugen Rochko': 11},
#              'spec/controllers/auth/sessions_controller_spec.rb': {'Eugen Rochko': 151},
#              'spec/lib/suspicious_sign_in_detector_spec.rb': {'Eugen Rochko': 57},
#              'spec/mailers/previews/user_mailer_preview.rb': {'Eugen Rochko': 6},
#              'app/services/activitypub/fetch_featured_collection_service.rb': {'Claire': 52,
#               'Jeong Arm': 2},
#              'app/services/activitypub/process_status_update_service.rb': {'Claire': 50,
#               'Eugen Rochko': 49},
#              'spec/services/activitypub/fetch_remote_status_service_spec.rb': {'Claire': 44},
#              'spec/services/activitypub/process_status_update_service_spec.rb': {'Claire': 178},
#              'config/environments/production.rb': {'Eugen Rochko': 5,
#               'Yamagishi Kazutoshi': 2},
#              'spec/mailers/user_mailer_spec.rb': {'Claire': 11},
#              'app/controllers/api/v1/trends/links_controller.rb': {'Eugen Rochko': 6},
#              'app/controllers/api/v1/trends/statuses_controller.rb': {'Eugen Rochko': 6},
#              'app/models/trends/query.rb': {'Eugen Rochko': 13},
#              'lib/mastodon/migration_helpers.rb': {'Claire': 5},
#              'config/initializers/devise.rb': {'Eugen Rochko': 4},
#              'config/initializers/session_store.rb': {'Eugen Rochko': 2},
#              'app/models/trends/base.rb': {'Eugen Rochko': 49},
#              'app/models/trends/statuses.rb': {'Eugen Rochko': 100},
#              'app/controllers/settings/preferences_controller.rb': {'Eugen Rochko': 3},
#              'app/lib/user_settings_decorator.rb': {'Eugen Rochko': 5},
#              'app/services/notify_service.rb': {'Eugen Rochko': 63},
#              'app/controllers/api/v1/statuses_controller.rb': {'Claire': 6},
#              'app/models/trends/links.rb': {'Eugen Rochko': 47},
#              'app/controllers/api/v2/search_controller.rb': {'0x2019': 4},
#              'app/lib/search_query_transformer.rb': {'0x2019': 8},
#              'lib/exceptions.rb': {'0x2019': 1},
#              'app/models/account_alias.rb': {'Claire': 5},
#              'app/serializers/web/notification_serializer.rb': {'Claire': 2},
#              'app/models/account.rb': {'Claire': 15},
#              'app/models/concerns/account_finder_concern.rb': {'Claire': 2},
#              'db/migrate/20190715164535_add_instance_actor.rb': {'Claire': 8},
#              'app/lib/activitypub/activity/create.rb': {'Claire': 2,
#               'Eugen Rochko': 4},
#              'spec/lib/activitypub/activity/create_spec.rb': {'Claire': 52},
#              'db/migrate/20220428112511_add_index_statuses_on_account_id.rb': {'Claire': 7},
#              'db/migrate/20220428112727_add_index_statuses_pins_on_status_id.rb': {'Claire': 7},
#              'db/migrate/20220428114454_add_index_reports_on_assigned_account_id.rb': {'Claire': 7},
#              'db/migrate/20220428114902_add_index_reports_on_action_taken_by_account_id.rb': {'Claire': 7},
#              'db/schema.rb': {'Claire': 7, 'Eugen Rochko': 4},
#              'app/controllers/admin/dashboard_controller.rb': {'Eugen Rochko': 8},
#              'app/controllers/media_proxy_controller.rb': {'Eugen Rochko': 20},
#              'app/controllers/settings/exports_controller.rb': {'Eugen Rochko': 18},
#              'app/lib/access_token_extension.rb': {'Eugen Rochko': 4},
#              'app/lib/activitypub/activity.rb': {'Eugen Rochko': 19},
#              'app/lib/delivery_failure_tracker.rb': {'Eugen Rochko': 18},
#              'app/lib/redis_configuration.rb': {'Eugen Rochko': 54},
#              'app/models/account_conversation.rb': {'Eugen Rochko': 4},
#              'app/models/account_suggestions/global_source.rb': {'Eugen Rochko': 4},
#              'app/models/concerns/redisable.rb': {'Eugen Rochko': 12},
#              'app/models/custom_filter.rb': {'Eugen Rochko': 3},
#              'app/models/encrypted_message.rb': {'Eugen Rochko': 3},
#              'app/models/follow_recommendation_filter.rb': {'Eugen Rochko': 4},
#              'app/services/activitypub/process_account_service.rb': {'Eugen Rochko': 36},
#              'app/services/fan_out_on_write_service.rb': {'Eugen Rochko': 14},
#              'app/services/fetch_link_card_service.rb': {'Eugen Rochko': 19},
#              'app/services/precompute_feed_service.rb': {'Eugen Rochko': 4},
#              'app/services/resolve_account_service.rb': {'Eugen Rochko': 16,
#               'Claire': 2},
#              'app/services/vote_service.rb': {'Eugen Rochko': 24},
#              'app/workers/distribution_worker.rb': {'Eugen Rochko': 12},
#              'app/workers/merge_worker.rb': {'Eugen Rochko': 3},
#              'app/workers/scheduler/accounts_statuses_cleanup_scheduler.rb': {'Eugen Rochko': 7},
#              'config/initializers/sidekiq.rb': {'Eugen Rochko': 4},
#              'lib/mastodon/feeds_cli.rb': {'Eugen Rochko': 7},
#              'lib/mastodon/rack_middleware.rb': {'Eugen Rochko': 32},
#              'lib/mastodon/redis_config.rb': {'Eugen Rochko': 22},
#              'lib/mastodon/sidekiq_middleware.rb': {'Eugen Rochko': 23},
#              'spec/controllers/concerns/user_tracking_concern_spec.rb': {'Eugen Rochko': 8},
#              'spec/lib/activitypub/activity/move_spec.rb': {'Eugen Rochko': 4},
#              'spec/lib/delivery_failure_tracker_spec.rb': {'Eugen Rochko': 2},
#              'spec/lib/feed_manager_spec.rb': {'Eugen Rochko': 28},
#              'spec/models/home_feed_spec.rb': {'Eugen Rochko': 4},
#              'spec/rails_helper.rb': {'Eugen Rochko': 4},
#              'spec/services/after_block_service_spec.rb': {'Eugen Rochko': 8},
#              'spec/services/batched_remove_status_service_spec.rb': {'Eugen Rochko': 6},
#              'spec/services/fan_out_on_write_service_spec.rb': {'Eugen Rochko': 22},
#              'spec/services/mute_service_spec.rb': {'Eugen Rochko': 4},
#              'spec/services/precompute_feed_service_spec.rb': {'Eugen Rochko': 4},
#              'spec/workers/scheduler/feed_cleanup_scheduler_spec.rb': {'Eugen Rochko': 16},
#              'config/initializers/stoplight.rb': {'Claire': 2,
#               'Eugen Rochko': 6},
#              'app/services/resolve_url_service.rb': {'Claire': 5},
#              'spec/services/resolve_url_service_spec.rb': {'Claire': 35},
#              'app/controllers/api/v1/bookmarks_controller.rb': {'Claire': 2},
#              'app/controllers/api/v1/favourites_controller.rb': {'Claire': 2},
#              'app/models/trends/tags.rb': {'Eugen Rochko': 17},
#              'lib/mastodon/cli_helper.rb': {'Eugen Rochko': 12},
#              'lib/mastodon/search_cli.rb': {'Eugen Rochko': 136},
#              'spec/services/resolve_account_service_spec.rb': {'Eugen Rochko': 2},
#              'app/models/email_domain_block.rb': {'Eugen Rochko': 24},
#              'app/validators/email_mx_validator.rb': {'Eugen Rochko': 6},
#              'db/migrate/20180615122121_add_autofollow_to_invites.rb': {'Eugen Rochko': 2},
#              'db/post_migrate/20220429101025_remove_ips_from_email_domain_blocks.rb': {'Eugen Rochko': 12},
#              'db/post_migrate/20220429101850_clear_email_domain_blocks.rb': {'Eugen Rochko': 14},
#              'spec/validators/email_mx_validator_spec.rb': {'Eugen Rochko': 60},
#              'app/lib/webfinger.rb': {'Eugen Rochko': 13},
#              'app/controllers/oauth/tokens_controller.rb': {'Eugen Rochko': 3},
#              'app/controllers/authorize_interactions_controller.rb': {'Eugen Rochko': 8},
#              'app/controllers/following_accounts_controller.rb': {'Eugen Rochko': 5},
#              'app/controllers/api/v1/accounts/lookup_controller.rb': {'Claire': 2},
#              'spec/services/activitypub/fetch_featured_collection_service_spec.rb': {'Claire': 123},
#              'lib/mastodon/settings_cli.rb': {'Claire': 14},
#              'app/services/verify_link_service.rb': {'Sara Golemon': 2},
#              'app/helpers/statuses_helper.rb': {'Stefano Pigozzi': 2},
#              'app/models/admin/account_action.rb': {'Claire': 8},
#              'app/controllers/accounts_controller.rb': {'Eugen Rochko': 1},
#              'app/controllers/tags_controller.rb': {'Eugen Rochko': 1},
#              'app/lib/emoji_formatter.rb': {'Eugen Rochko': 28},
#              'app/lib/rss/builder.rb': {'Eugen Rochko': 33},
#              'app/lib/rss/channel.rb': {'Eugen Rochko': 49},
#              'app/lib/rss/element.rb': {'Eugen Rochko': 24},
#              'app/lib/rss/item.rb': {'Eugen Rochko': 45},
#              'app/lib/rss/media_content.rb': {'Eugen Rochko': 35},
#              'spec/lib/emoji_formatter_spec.rb': {'Eugen Rochko': 6},
#              'spec/controllers/settings/two_factor_authentication/confirmations_controller_spec.rb': {'luzpaz': 4},
#              'app/serializers/rest/account_serializer.rb': {'Eugen Rochko': 7},
#              'app/lib/activitypub/activity/announce.rb': {'Eugen Rochko': 2,
#               'Yamagishi Kazutoshi': 2},
#              'app/lib/activitypub/activity/delete.rb': {'Eugen Rochko': 6},
#              'app/models/account_migration.rb': {'Eugen Rochko': 13},
#              'app/models/concerns/lockable.rb': {'Eugen Rochko': 19},
#              'app/serializers/initial_state_serializer.rb': {'Eugen Rochko': 8},
#              'app/serializers/rest/preferences_serializer.rb': {'Eugen Rochko': 2},
#              'app/services/activitypub/fetch_remote_status_service.rb': {'Claire': 1},
#              'spec/services/fetch_remote_status_service_spec.rb': {'Claire': 6},
#              'app/chewy/accounts_index.rb': {'Eugen Rochko': 8},
#              'app/chewy/tags_index.rb': {'Eugen Rochko': 10},
#              'app/workers/scheduler/indexing_scheduler.rb': {'Eugen Rochko': 26},
#              'config/initializers/chewy.rb': {'Eugen Rochko': 5},
#              'lib/chewy/strategy/mastodon.rb': {'Eugen Rochko': 27},
#              'app/lib/importer/accounts_index_importer.rb': {'Eugen Rochko': 30},
#              'app/lib/importer/base_importer.rb': {'Eugen Rochko': 87},
#              'app/lib/importer/statuses_index_importer.rb': {'Eugen Rochko': 89},
#              'app/lib/importer/tags_index_importer.rb': {'Eugen Rochko': 26},
#              'app/models/trends/history.rb': {'Eugen Rochko': 20},
#              'app/controllers/api/v1/accounts_controller.rb': {'Claire': 10},
#              'app/services/process_mentions_service.rb': {'Claire': 3},
#              'spec/models/account_spec.rb': {'Claire': 178},
#              'app/models/poll.rb': {'Eugen Rochko': 5},
#              'app/models/account_stat.rb': {'Eugen Rochko': 12},
#              'app/models/status_stat.rb': {'Eugen Rochko': 12},
#              'app/controllers/auth/confirmations_controller.rb': {'Eugen Rochko': 2},
#              'app/lib/application_extension.rb': {'Eugen Rochko': 4},
#              'config/initializers/doorkeeper.rb': {'Eugen Rochko': 7},
#              'app/controllers/activitypub/base_controller.rb': {'Eugen Rochko': 1},
#              'app/controllers/api/base_controller.rb': {'Eugen Rochko': 5},
#              'app/services/approve_appeal_service.rb': {'Eugen Rochko': 3},
#              'app/models/admin/status_batch_action.rb': {'Eugen Rochko': 6},
#              'app/services/report_service.rb': {'Eugen Rochko': 2},
#              'app/services/appeal_service.rb': {'Eugen Rochko': 3},
#              'app/services/unfollow_service.rb': {'Eugen Rochko': 6},
#              'app/helpers/languages_helper.rb': {'Eugen Rochko': 4}})

# %%
contribs_data = {}

for file, author_contribs in files_authors.items():
    total_contribs = sum(author_contribs.values())
    current_percentages = {}
    main_author = None
    max_author_percentage = 0
    if total_contribs != 0:
        for author, contribs in author_contribs.items():
            author_percentage = contribs / total_contribs
            if author_percentage > max_author_percentage:
                max_author_percentage = author_percentage
                main_author = author
        
        contribs_data[file] = {
            "main_author": main_author,
            "main_author_percentage": round(max_author_percentage, 2),
            "total_contribs": total_contribs
        }
        
        
contribs_data
# Out:
# {'lib/mastodon/version.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.75,
#   'total_contribs': 8},
#  'app/chewy/statuses_index.rb': {'main_author': 'Jeong Arm',
#   'main_author_percentage': 0.45,
#   'total_contribs': 11},
#  'app/helpers/formatting_helper.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.97,
#   'total_contribs': 29},
#  'app/lib/feed_manager.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.74,
#   'total_contribs': 31},
#  'app/models/status.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.87,
#   'total_contribs': 15},
#  'app/serializers/manifest_serializer.rb': {'main_author': 'Holger',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'config/application.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.83,
#   'total_contribs': 6},
#  'config/initializers/paperclip.rb': {'main_author': 'Holger',
#   'main_author_percentage': 1.0,
#   'total_contribs': 20},
#  'app/helpers/application_helper.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.54,
#   'total_contribs': 13},
#  'app/serializers/rest/status_serializer.rb': {'main_author': 'rinsuki',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/controllers/api/v1/trends/tags_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/controllers/api/v1/admin/account_actions_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/accounts_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/controllers/api/v1/admin/dimensions_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/measures_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/reports_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/retention_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/trends/links_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/trends/statuses_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/admin/trends/tags_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/services/remove_status_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.94,
#   'total_contribs': 67},
#  'app/controllers/auth/sessions_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 9},
#  'app/lib/suspicious_sign_in_detector.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 42},
#  'app/mailers/user_mailer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.92,
#   'total_contribs': 13},
#  'app/models/user.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 24},
#  'app/policies/user_policy.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'config/routes.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'lib/mastodon/accounts_cli.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 11},
#  'spec/controllers/auth/sessions_controller_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 151},
#  'spec/lib/suspicious_sign_in_detector_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 57},
#  'spec/mailers/previews/user_mailer_preview.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/services/activitypub/fetch_featured_collection_service.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.96,
#   'total_contribs': 54},
#  'app/services/activitypub/process_status_update_service.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.51,
#   'total_contribs': 99},
#  'spec/services/activitypub/fetch_remote_status_service_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 44},
#  'spec/services/activitypub/process_status_update_service_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 178},
#  'config/environments/production.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.71,
#   'total_contribs': 7},
#  'spec/mailers/user_mailer_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 11},
#  'app/controllers/api/v1/trends/links_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/controllers/api/v1/trends/statuses_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/models/trends/query.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 13},
#  'lib/mastodon/migration_helpers.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'config/initializers/devise.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'config/initializers/session_store.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/models/trends/base.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 49},
#  'app/models/trends/statuses.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 100},
#  'app/controllers/settings/preferences_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/lib/user_settings_decorator.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/services/notify_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 63},
#  'app/controllers/api/v1/statuses_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/models/trends/links.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 47},
#  'app/controllers/api/v2/search_controller.rb': {'main_author': '0x2019',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/lib/search_query_transformer.rb': {'main_author': '0x2019',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'lib/exceptions.rb': {'main_author': '0x2019',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'app/models/account_alias.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/serializers/web/notification_serializer.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/models/account.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 15},
#  'app/models/concerns/account_finder_concern.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'db/migrate/20190715164535_add_instance_actor.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/lib/activitypub/activity/create.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.67,
#   'total_contribs': 6},
#  'spec/lib/activitypub/activity/create_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 52},
#  'db/migrate/20220428112511_add_index_statuses_on_account_id.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'db/migrate/20220428112727_add_index_statuses_pins_on_status_id.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'db/migrate/20220428114454_add_index_reports_on_assigned_account_id.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'db/migrate/20220428114902_add_index_reports_on_action_taken_by_account_id.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'db/schema.rb': {'main_author': 'Claire',
#   'main_author_percentage': 0.64,
#   'total_contribs': 11},
#  'app/controllers/admin/dashboard_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/controllers/media_proxy_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 20},
#  'app/controllers/settings/exports_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 18},
#  'app/lib/access_token_extension.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/lib/activitypub/activity.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 19},
#  'app/lib/delivery_failure_tracker.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 18},
#  'app/lib/redis_configuration.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 54},
#  'app/models/account_conversation.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/models/account_suggestions/global_source.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/models/concerns/redisable.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'app/models/custom_filter.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/models/encrypted_message.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/models/follow_recommendation_filter.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/services/activitypub/process_account_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 36},
#  'app/services/fan_out_on_write_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 14},
#  'app/services/fetch_link_card_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 19},
#  'app/services/precompute_feed_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/services/resolve_account_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.89,
#   'total_contribs': 18},
#  'app/services/vote_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 24},
#  'app/workers/distribution_worker.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'app/workers/merge_worker.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/workers/scheduler/accounts_statuses_cleanup_scheduler.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'config/initializers/sidekiq.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'lib/mastodon/feeds_cli.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'lib/mastodon/rack_middleware.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 32},
#  'lib/mastodon/redis_config.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 22},
#  'lib/mastodon/sidekiq_middleware.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 23},
#  'spec/controllers/concerns/user_tracking_concern_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'spec/lib/activitypub/activity/move_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'spec/lib/delivery_failure_tracker_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'spec/lib/feed_manager_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 28},
#  'spec/models/home_feed_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'spec/rails_helper.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'spec/services/after_block_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'spec/services/batched_remove_status_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'spec/services/fan_out_on_write_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 22},
#  'spec/services/mute_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'spec/services/precompute_feed_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'spec/workers/scheduler/feed_cleanup_scheduler_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 16},
#  'config/initializers/stoplight.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.75,
#   'total_contribs': 8},
#  'app/services/resolve_url_service.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'spec/services/resolve_url_service_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 35},
#  'app/controllers/api/v1/bookmarks_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/controllers/api/v1/favourites_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/models/trends/tags.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 17},
#  'lib/mastodon/cli_helper.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'lib/mastodon/search_cli.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 136},
#  'spec/services/resolve_account_service_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/models/email_domain_block.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 24},
#  'app/validators/email_mx_validator.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'db/migrate/20180615122121_add_autofollow_to_invites.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'db/post_migrate/20220429101025_remove_ips_from_email_domain_blocks.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'db/post_migrate/20220429101850_clear_email_domain_blocks.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 14},
#  'spec/validators/email_mx_validator_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 60},
#  'app/lib/webfinger.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 13},
#  'app/controllers/oauth/tokens_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/controllers/authorize_interactions_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/controllers/following_accounts_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/controllers/api/v1/accounts/lookup_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'spec/services/activitypub/fetch_featured_collection_service_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 123},
#  'lib/mastodon/settings_cli.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 14},
#  'app/services/verify_link_service.rb': {'main_author': 'Sara Golemon',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/helpers/statuses_helper.rb': {'main_author': 'Stefano Pigozzi',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/models/admin/account_action.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/controllers/accounts_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'app/controllers/tags_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'app/lib/emoji_formatter.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 28},
#  'app/lib/rss/builder.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 33},
#  'app/lib/rss/channel.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 49},
#  'app/lib/rss/element.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 24},
#  'app/lib/rss/item.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 45},
#  'app/lib/rss/media_content.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 35},
#  'spec/lib/emoji_formatter_spec.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'spec/controllers/settings/two_factor_authentication/confirmations_controller_spec.rb': {'main_author': 'luzpaz',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'app/serializers/rest/account_serializer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'app/lib/activitypub/activity/announce.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 0.5,
#   'total_contribs': 4},
#  'app/lib/activitypub/activity/delete.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/models/account_migration.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 13},
#  'app/models/concerns/lockable.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 19},
#  'app/serializers/initial_state_serializer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/serializers/rest/preferences_serializer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/services/activitypub/fetch_remote_status_service.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'spec/services/fetch_remote_status_service_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/chewy/accounts_index.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 8},
#  'app/chewy/tags_index.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 10},
#  'app/workers/scheduler/indexing_scheduler.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 26},
#  'config/initializers/chewy.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'lib/chewy/strategy/mastodon.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 27},
#  'app/lib/importer/accounts_index_importer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 30},
#  'app/lib/importer/base_importer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 87},
#  'app/lib/importer/statuses_index_importer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 89},
#  'app/lib/importer/tags_index_importer.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 26},
#  'app/models/trends/history.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 20},
#  'app/controllers/api/v1/accounts_controller.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 10},
#  'app/services/process_mentions_service.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'spec/models/account_spec.rb': {'main_author': 'Claire',
#   'main_author_percentage': 1.0,
#   'total_contribs': 178},
#  'app/models/poll.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/models/account_stat.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'app/models/status_stat.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 12},
#  'app/controllers/auth/confirmations_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/lib/application_extension.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4},
#  'config/initializers/doorkeeper.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 7},
#  'app/controllers/activitypub/base_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 1},
#  'app/controllers/api/base_controller.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 5},
#  'app/services/approve_appeal_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/models/admin/status_batch_action.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/services/report_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 2},
#  'app/services/appeal_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 3},
#  'app/services/unfollow_service.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 6},
#  'app/helpers/languages_helper.rb': {'main_author': 'Eugen Rochko',
#   'main_author_percentage': 1.0,
#   'total_contribs': 4}}

# %% [markdown]
# # **GIT UNIX Shell**

# %%
# run inside \mastodon\app
git ls-files | awk -F . '{print $NF}' | sort | uniq -c | sort -n -r | awk '{print $2,$1}' | head -10
rb 895
js 437
haml 214
json 178
png 37
erb 33
scss 32
svg 24
woff2 5
woff 5

# ls-files iterates through each line
# awk -F --> sepeartor -f-->reads from file not first line argument
# print $NF --> counts number of fields within current input record
# print $2$1 --> print second column first, then first column


find . -type f -name "*.rb" | awk -F / '{print $(NF)}' > mastodon_../rubyfiles.txt
# find names of ruby files and store them in a listcat


#week 8 slide 19
git log --numstat --since "Jan 1 2019" --until "DEC 31 2019" > ../commits2019.txt --> writes 
git log --numstat -n 1 cfd49dd646c0e13fa54645ff27a5c59c1f96dc8b
cat logs.log | grep ".java" | awk -F '\t' '{print $3}' | sort | uniq –c
# Out:
#   Cell In[17], line 27
#     cat logs.log | grep ".java" | awk -F '\t' '{print $3}' | sort | uniq –c
#                                                                          ^
# SyntaxError: invalid character '–' (U+2013)
